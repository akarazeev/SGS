# %%
import json

from watson_developer_cloud import NaturalLanguageUnderstandingV1
import watson_developer_cloud.natural_language_understanding.features.v1 as Features

# %%
natural_language_understanding = NaturalLanguageUnderstandingV1(
    username="99a0f3e5-81ff-415d-a707-44b58592002c",  # PASS HERE YOUR _USERNAME_
    password="aV2NgEWjhPo0",                          # PASS HERE YOUR _PASSWORD_
    version="2017-02-27"
)

# %%
with open('001/0a1de5aa-a33b-4bbd-877b-54e799844456', 'r') as f:
    data = f.read()

# %%
print(data)
# Out:
# The INIFAP generated technology that reduces the time of harvesting of teberana agave Weber through the technique of fertigation.
# The researcher at the Las Huastecas Experimental Field of the National Institute of Forestry, Agriculture and Livestock Research (INIFAP), Lamberto Zúñiga Estrada, pointed out that fertigation is an intensive production technique, used worldwide in open pit production systems and in The protected agriculture, that has allowed to improve the yield and quality in cultures of grains, vegetables and fruit trees.
# "Fertigation consists of simultaneously applying water and nutrients through a pressurized irrigation system (drip); The application is made with high frequency and uniform to moisten the soil where the root is more active, which allows the water and the fertilizer to be used efficiently by the plant. As a consequence, yield increases and the cost per ton produced is lower, as well as groundwater contamination by fertilizer leaching, "he said.
# Zúñiga Estrada pointed out that in order to evaluate the agave With the fertigation technique, eight destructive evaluations or samplings (September 2004, February 2005 and October 2005-2010) of plants established in ten soil fertility conditions induced by fertilizers were carried out during the crop cycle; The agronomic characteristics of the plant were measured: height and diameter, number of leaves, weight of pineapple and reducing sugars in the pineapple.
# Also, the wet weight and dry matter of leaves, pineapple, sprouts, roots and bud were evaluated; (N), phosphorus (P), potassium (K), calcium (Ca) and magnesium (Mg) were determined in the dry matter of each organ, according to the member of the Mexican Society of Horticultural Sciences (Somech).
# According to the researcher, the study was carried out in Tamaulipas in response to demands for technology from producers in the southern state, where the cultivation of agave was introduced in the year 2000 as an alternative production Of raw material for the Jalisco tequila industry. Its planting was legally justified in the Certificate of Denomination of Origin Tequila obtained since 1977 in 11 municipalities of the south of Tamaulipas.
# Dr. Zúñiga Estrada emphasized that the information generated allowed us to document the dynamics of dry matter accumulation and the extraction of nutrients in foliage and pineapple, determining the nutritional demands of the agave plant in different stages of development, as well as the amount of Nutrients that the agave requires to generate a ton of pineapple.
# "This information is basic to define a program of management of fertilizers according to the stage of development of the crop and the performance that is intended to be achieved. The nutritional demands generated in Tamaulipas should be adjusted in each region or agave producing area according to the physical and chemical characteristics of the soils and the target yield sought, "he said.
# Although the research project funded by the Produce Tamaulipas Foundation has already ended, the INIFAP specialist said that it intends to work in different regions and species of agave.
# "It is necessary to disseminate this experience in the various agave producing areas, to demonstrate in the field of technology producers, to adjust in each region the nutrition information generated and to continue studies to efficiently manage water and nutrients in agave cultivation, Under a multidisciplinary and interinstitutional approach, "he concluded.
# Source: Conacyt Information Agency / www.conacytprensa.mx

# %%
response = natural_language_understanding.analyze(
    text=data,
    features=[
        Features.Sentiment(),
        Features.Keywords(),
        Features.Entities(
          sentiment=True,
#           limit=10
        ),
        Features.Categories(),
        Features.Concepts()
    ]
)

# %%
print(json.dumps(response, indent=2))
# Out:
# {
#   "usage": {
#     "text_units": 1,
#     "text_characters": 3559,
#     "features": 5
#   },
#   "sentiment": {
#     "document": {
#       "score": 0.719027,
#       "label": "positive"
#     }
#   },
#   "language": "en",
#   "keywords": [
#     {
#       "text": "Z\u00fa\u00f1iga Estrada",
#       "relevance": 0.984726
#     },
#     {
#       "text": "various agave producing",
#       "relevance": 0.921207
#     },
#     {
#       "text": "dry matter",
#       "relevance": 0.876952
#     },
#     {
#       "text": "Lamberto Z\u00fa\u00f1iga Estrada",
#       "relevance": 0.842233
#     },
#     {
#       "text": "Produce Tamaulipas Foundation",
#       "relevance": 0.815913
#     },
#     {
#       "text": "agave plant",
#       "relevance": 0.813584
#     },
#     {
#       "text": "Las Huastecas Experimental",
#       "relevance": 0.813202
#     },
#     {
#       "text": "agave cultivation",
#       "relevance": 0.802052
#     },
#     {
#       "text": "intensive production technique",
#       "relevance": 0.79536
#     },
#     {
#       "text": "open pit production",
#       "relevance": 0.79464
#     },
#     {
#       "text": "Dr. Z\u00fa\u00f1iga Estrada",
#       "relevance": 0.789223
#     },
#     {
#       "text": "nutritional demands",
#       "relevance": 0.779362
#     },
#     {
#       "text": "simultaneously applying water",
#       "relevance": 0.775469
#     },
#     {
#       "text": "Jalisco tequila industry",
#       "relevance": 0.768485
#     },
#     {
#       "text": "soil fertility conditions",
#       "relevance": 0.761788
#     },
#     {
#       "text": "dry matter accumulation",
#       "relevance": 0.761179
#     },
#     {
#       "text": "Conacyt Information Agency",
#       "relevance": 0.748544
#     },
#     {
#       "text": "fertigation technique",
#       "relevance": 0.719542
#     },
#     {
#       "text": "pineapple",
#       "relevance": 0.67828
#     },
#     {
#       "text": "yield increases",
#       "relevance": 0.670235
#     },
#     {
#       "text": "National Institute",
#       "relevance": 0.661265
#     },
#     {
#       "text": "fruit trees",
#       "relevance": 0.659623
#     },
#     {
#       "text": "protected agriculture",
#       "relevance": 0.655767
#     },
#     {
#       "text": "Livestock Research",
#       "relevance": 0.653456
#     },
#     {
#       "text": "agronomic characteristics",
#       "relevance": 0.648751
#     },
#     {
#       "text": "target yield",
#       "relevance": 0.645554
#     },
#     {
#       "text": "crop cycle",
#       "relevance": 0.644297
#     },
#     {
#       "text": "high frequency",
#       "relevance": 0.643483
#     },
#     {
#       "text": "groundwater contamination",
#       "relevance": 0.642412
#     },
#     {
#       "text": "alternative production",
#       "relevance": 0.641513
#     },
#     {
#       "text": "destructive evaluations",
#       "relevance": 0.640907
#     },
#     {
#       "text": "nutrition information",
#       "relevance": 0.639996
#     },
#     {
#       "text": "southern state",
#       "relevance": 0.63942
#     },
#     {
#       "text": "Horticultural Sciences",
#       "relevance": 0.639194
#     },
#     {
#       "text": "raw material",
#       "relevance": 0.63891
#     },
#     {
#       "text": "Origin Tequila",
#       "relevance": 0.637368
#     },
#     {
#       "text": "wet weight",
#       "relevance": 0.637033
#     },
#     {
#       "text": "Mexican Society",
#       "relevance": 0.636338
#     },
#     {
#       "text": "technology producers",
#       "relevance": 0.63589
#     },
#     {
#       "text": "interinstitutional approach",
#       "relevance": 0.633112
#     },
#     {
#       "text": "nutrients",
#       "relevance": 0.632987
#     },
#     {
#       "text": "INIFAP specialist",
#       "relevance": 0.631522
#     },
#     {
#       "text": "chemical characteristics",
#       "relevance": 0.630506
#     },
#     {
#       "text": "research project",
#       "relevance": 0.629064
#     },
#     {
#       "text": "different stages",
#       "relevance": 0.628571
#     },
#     {
#       "text": "different regions",
#       "relevance": 0.622627
#     },
#     {
#       "text": "fertilizer",
#       "relevance": 0.555937
#     },
#     {
#       "text": "ton",
#       "relevance": 0.555616
#     },
#     {
#       "text": "fertilizers",
#       "relevance": 0.555014
#     }
#   ],
#   "entities": [
#     {
#       "type": "Person",
#       "text": "Lamberto Z\u00fa\u00f1iga Estrada",
#       "sentiment": {
#         "score": 0.0,
#         "label": "neutral"
#       },
#       "relevance": 0.912298,
#       "count": 4
#     },
#     {
#       "type": "Location",
#       "text": "Tamaulipas",
#       "sentiment": {
#         "score": 0.0,
#         "label": "neutral"
#       },
#       "relevance": 0.739146,
#       "disambiguation": {
#         "subtype": [
#           "City"
#         ]
#       },
#       "count": 3
#     },
#     {
#       "type": "Organization",
#       "text": "INIFAP",
#       "sentiment": {
#         "score": 0.0,
#         "label": "neutral"
#       },
#       "relevance": 0.48673,
#       "count": 2
#     },
#     {
#       "type": "Organization",
#       "text": "Produce Tamaulipas Foundation",
#       "sentiment": {
#         "score": 0.0,
#         "label": "neutral"
#       },
#       "relevance": 0.48648,
#       "count": 1
#     },
#     {
#       "type": "JobTitle",
#       "text": "researcher",
#       "sentiment": {
#         "score": 0.0,
#         "label": "neutral"
#       },
#       "relevance": 0.483959,
#       "count": 2
#     },
#     {
#       "type": "Organization",
#       "text": "Las Huastecas Experimental Field",
#       "sentiment": {
#         "score": 0.0,
#         "label": "neutral"
#       },
#       "relevance": 0.395828,
#       "count": 1
#     },
#     {
#       "type": "Organization",
#       "text": "Mexican Society of Horticultural Sciences",
#       "sentiment": {
#         "score": 0.0,
#         "label": "neutral"
#       },
#       "relevance": 0.356835,
#       "count": 1
#     },
#     {
#       "type": "Company",
#       "text": "INIFAP",
#       "sentiment": {
#         "score": 0.0,
#         "label": "neutral"
#       },
#       "relevance": 0.340884,
#       "count": 1
#     },
#     {
#       "type": "Company",
#       "text": "Conacyt Information Agency",
#       "sentiment": {
#         "score": 0.0,
#         "label": "neutral"
#       },
#       "relevance": 0.337195,
#       "count": 1
#     },
#     {
#       "type": "Organization",
#       "text": "National Institute of Forestry",
#       "sentiment": {
#         "score": 0.0,
#         "label": "neutral"
#       },
#       "relevance": 0.327468,
#       "count": 1
#     },
#     {
#       "type": "Location",
#       "text": "Jalisco",
#       "sentiment": {
#         "score": 0.0,
#         "label": "neutral"
#       },
#       "relevance": 0.312152,
#       "disambiguation": {
#         "subtype": [
#           "StateOrCounty"
#         ]
#       },
#       "count": 1
#     },
#     {
#       "type": "Organization",
#       "text": "Livestock Research",
#       "sentiment": {
#         "score": 0.0,
#         "label": "neutral"
#       },
#       "relevance": 0.309574,
#       "count": 1
#     },
#     {
#       "type": "Organization",
#       "text": "Somech",
#       "sentiment": {
#         "score": 0.0,
#         "label": "neutral"
#       },
#       "relevance": 0.285383,
#       "count": 1
#     }
#   ],
#   "concepts": [
#     {
#       "text": "Agriculture",
#       "relevance": 0.975524,
#       "dbpedia_resource": "http://dbpedia.org/resource/Agriculture"
#     },
#     {
#       "text": "Soil",
#       "relevance": 0.825112,
#       "dbpedia_resource": "http://dbpedia.org/resource/Soil"
#     },
#     {
#       "text": "Irrigation",
#       "relevance": 0.816079,
#       "dbpedia_resource": "http://dbpedia.org/resource/Irrigation"
#     },
#     {
#       "text": "Fertilizer",
#       "relevance": 0.750916,
#       "dbpedia_resource": "http://dbpedia.org/resource/Fertilizer"
#     },
#     {
#       "text": "Tequila",
#       "relevance": 0.709087,
#       "dbpedia_resource": "http://dbpedia.org/resource/Tequila"
#     },
#     {
#       "text": "Fruit",
#       "relevance": 0.657333,
#       "dbpedia_resource": "http://dbpedia.org/resource/Fruit"
#     },
#     {
#       "text": "Plant",
#       "relevance": 0.604083,
#       "dbpedia_resource": "http://dbpedia.org/resource/Plant"
#     },
#     {
#       "text": "Nutrition",
#       "relevance": 0.599032,
#       "dbpedia_resource": "http://dbpedia.org/resource/Nutrition"
#     }
#   ],
#   "categories": [
#     {
#       "score": 0.276395,
#       "label": "/travel/tourist destinations/mexico and central america"
#     },
#     {
#       "score": 0.250211,
#       "label": "/technology and computing"
#     },
#     {
#       "score": 0.234016,
#       "label": "/business and industrial/agriculture and forestry/crops and seed"
#     }
#   ]
# }
